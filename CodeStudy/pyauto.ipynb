# %%
import pyautogui as pag

# %%
pag.size()
# Out:
# Size(width=1920, height=1080)

# %%
try:
    old_pos = pag.position()
    while True:
        new_pos = pag.position()
        if new_pos != old_pos:
            print(new_pos)
            old_pos = new_pos
except KeyboardInterrupt:
    print("exit")
# Out:
# Point(x=351, y=255)
# Point(x=350, y=255)
# Point(x=350, y=256)
# Point(x=349, y=256)
# Point(x=349, y=257)
# Point(x=349, y=258)
# Point(x=349, y=259)
# Point(x=349, y=260)
# Point(x=349, y=261)
# Point(x=349, y=262)
# Point(x=349, y=263)
# Point(x=349, y=264)
# Point(x=349, y=265)
# Point(x=349, y=266)
# Point(x=349, y=267)
# Point(x=349, y=268)
# Point(x=349, y=269)
# Point(x=349, y=270)
# Point(x=349, y=271)
# Point(x=349, y=272)
# Point(x=349, y=274)
# Point(x=349, y=275)
# Point(x=348, y=276)
# Point(x=348, y=277)
# Point(x=348, y=278)
# Point(x=347, y=279)
# Point(x=347, y=280)
# Point(x=347, y=281)
# Point(x=347, y=282)
# Point(x=347, y=283)
# Point(x=346, y=284)
# Point(x=346, y=285)
# Point(x=345, y=287)
# Point(x=345, y=288)
# Point(x=345, y=289)
# Point(x=345, y=291)
# Point(x=344, y=291)
# Point(x=344, y=293)
# Point(x=344, y=295)
# Point(x=344, y=296)
# Point(x=344, y=298)
# Point(x=343, y=301)
# Point(x=343, y=303)
# Point(x=343, y=304)
# Point(x=342, y=307)
# ...

# %%
pag.moveTo(400, 500, duration=0.25)
