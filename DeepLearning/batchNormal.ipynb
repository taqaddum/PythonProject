# %%
import torch
from torch import nn

# %%
x = torch.rand(2, 3, 7, 7)
x
# Out:
# tensor([[[[6.7895e-01, 7.4499e-01, 1.8705e-01, 7.7797e-01, 5.6752e-01,
#            6.2714e-01, 4.5457e-01],
#           [9.9173e-03, 8.2250e-01, 2.0598e-01, 3.6761e-01, 5.1073e-01,
#            5.9754e-01, 5.7213e-01],
#           [3.1266e-01, 7.8205e-01, 3.7684e-02, 1.5389e-02, 7.7259e-01,
#            8.8104e-01, 3.5374e-01],
#           [9.5725e-01, 7.3094e-01, 3.1064e-01, 6.3367e-02, 2.1063e-01,
#            9.0066e-01, 1.3974e-01],
#           [7.8472e-01, 8.9680e-01, 5.2119e-01, 8.4320e-01, 6.6866e-01,
#            5.6896e-01, 3.3304e-01],
#           [5.6252e-02, 9.2198e-01, 3.7701e-01, 3.1397e-01, 8.0050e-02,
#            1.1254e-01, 2.9687e-01],
#           [2.9544e-01, 4.5662e-01, 8.3824e-01, 5.8908e-01, 6.5388e-01,
#            4.3721e-01, 4.4113e-01]],
#
#          [[7.5279e-01, 7.6277e-01, 4.3397e-01, 4.2675e-01, 5.6322e-01,
#            8.0902e-01, 8.1756e-01],
#           [8.2276e-01, 3.6532e-02, 3.7626e-02, 6.4779e-01, 5.8264e-01,
# ...

# %%
net = nn.BatchNorm2d(3)
net(x)
# Out:
# tensor([[[[ 7.0453e-01,  9.5821e-01, -1.1852e+00,  1.0849e+00,  2.7644e-01,
#             5.0548e-01, -1.5748e-01],
#           [-1.8657e+00,  1.2560e+00, -1.1125e+00, -4.9153e-01,  5.8262e-02,
#             3.9177e-01,  2.9416e-01],
#           [-7.0263e-01,  1.1006e+00, -1.7590e+00, -1.8447e+00,  1.0643e+00,
#             1.4809e+00, -5.4484e-01],
#           [ 1.7736e+00,  9.0424e-01, -7.1040e-01, -1.6603e+00, -1.0946e+00,
#             1.5563e+00, -1.3670e+00],
#           [ 1.1108e+00,  1.5414e+00,  9.8452e-02,  1.3355e+00,  6.6500e-01,
#             2.8196e-01, -6.2436e-01],
#           [-1.6877e+00,  1.6382e+00, -4.5541e-01, -6.9760e-01, -1.5963e+00,
#            -1.4714e+00, -7.6332e-01],
#           [-7.6879e-01, -1.4959e-01,  1.3164e+00,  3.5926e-01,  6.0822e-01,
#            -2.2414e-01, -2.0911e-01]],
#
#          [[ 8.1747e-01,  8.5056e-01, -2.3971e-01, -2.6364e-01,  1.8888e-01,
#             1.0039e+00,  1.0322e+00],
# ...

# %%
def batch_norm(x):
    return torch.mean(x, dim=(0, 2, 3), keepdim=True)

# %%
batch_norm(x).shape
# Out:
# torch.Size([1, 3, 1, 1])
