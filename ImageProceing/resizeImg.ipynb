# %%
from PIL import Image
from pathlib import Path
from torchvision import transforms
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = Image.open(r"C:\Users\jhZou\Pictures\Saved Pictures\Arknights.jpg")
transformer = transforms.Resize([500, 900])
plt.figure(num=1, figsize=(9, 6), dpi=100)
plt.imshow(transformer(img))
plt.axis("off")
plt.show()
